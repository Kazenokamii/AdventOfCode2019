               223,1006,224,614,1001,223,1,223,1108,677,226,224,1002,223,2,223,1005,224,629,1001,223,1,223,1007,677,677,224,
               102,2,223,223,1006,224,644,1001,223,1,223,108,226,677,224,102,2,223,223,1005,224,659,101,1,223,223,8,677,226,
               224,1002,223,2,223,1006,224,674,1001,223,1,223,4,223,99,226]

# %%
def intCode(x):
    k = 0
    while k < len(x):
        print(k)
        wait = input("PRESS ENTER TO CONTINUE.")
        if x[k] == 99:
            break
        operator = str(x[k])
        if len(operator) == 1:
            if operator == '1':
                print('Operator = ' + operator)
                inputOne = x[x[k+1]]
                inputTwo = x[x[k+2]]
                outputPosition = x[k+3]
                x[outputPosition] = inputOne + inputTwo
                k = k+4
            elif operator == '2':
                print('Operator = ' + operator)
                inputOne = x[x[k+1]]
                inputTwo = x[x[k+2]]
                outputPosition = x[k+3]
                x[outputPosition] = inputOne * inputTwo
                k = k+4
            elif operator == '3':
                print('Operator = ' + operator)
                inputOne = int(input("Enter an Integer: "))
                outputPosition = x[k+1]
                x[outputPosition] = inputOne
                k = k+2
            elif operator == '4':
                print('Operator = ' + operator)
                displayOutput = x[x[k+1]]
                print('Test Value should be 0: ' + str(displayOutput))
                k = k+2
            elif operator == '5':
                inputOne = x[x[k+1]]
                inputTwo = x[x[k+2]]
                if inputOne != 0:
                    k = inputTwo
                else:
                    k = k+3
            elif operator == '6':
                inputOne = x[x[k+1]]
                inputTwo = x[x[k+2]]
                if inputOne == 0:
                    k = inputTwo
                else:
                    k = k+3
            elif operator == '7':
                inputOne = x[x[k+1]]
                inputTwo = x[x[k+2]]
                if inputOne < inputTwo:
                    x[x[k+3]] = 1
                else:
                    x[x[k+3]] = 0
                k = k+4
            elif operator == '8':
                inputOne = x[x[k+1]]
                inputTwo = x[x[k+2]]
                if inputOne == inputTwo:
                    x[x[k+3]] = 1
                else:
                    x[x[k+3]] = 0
                k = k+4
        else:
            modeOperator = str(x[k])[-2:]
            if modeOperator == '01':
                print('Operator = ' + operator)
                if len(operator) == 3:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = 0
                elif len(operator) == 4:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = str(x[k])[-4]
                if inputOneMode == '1':
                    inputOne = x[k+1]
                else:
                    inputOne = x[x[k+1]]
                if inputTwoMode == '1':
                    inputTwo = x[k+2]
                else:
                    inputTwo = x[x[k+2]]
                x[x[k+3]] = inputOne + inputTwo
                k = k+4
            elif modeOperator == '02':
                print('Operator = ' + operator)
                if len(operator) == 3:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = 0
                elif len(operator) == 4:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = str(x[k])[-4]
                if inputOneMode == '1':
                    inputOne = x[k+1]
                else:
                    inputOne = x[x[k+1]]
                if inputTwoMode == '1':
                    inputTwo = x[k+2]
                else:
                    inputTwo = x[x[k+2]]
                x[x[k+3]] = inputOne * inputTwo
                k = k+4
            elif modeOperator == '03':
                print('Operator = ' + operator)
                inputOne = int(input("Enter an Integer: "))
                outputPosition = x[k+1]
                x[outputPosition] = inputOne
                k = k+2
            elif modeOperator == '04':
                print('Operator = ' + operator)
                inputOneMode = inputOneMode = str(x[k])[-3]
                if inputOneMode == '1':
                    print('Test Value should be 0: ' + str(x[k+1]))
                else:
                    print('Test Value should be 0: ' + str(x[x[k+1]]))
                k = k+2
            elif modeOperator == '05':
                if len(operator) == 3:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = 0
                elif len(operator) == 4:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = str(x[k])[-4]
                if inputOneMode == '1':
                    inputOne = x[k+1]
                else:
                    inputOne = x[x[k+1]]
                if inputTwoMode == '1':
                    inputTwo = x[k+2]
                else:
                    inputTwo = x[x[k+2]]
                if inputOne != 0:
                    k = inputTwo
                else:
                    k = k+3
            elif modeOperator == '06':
                if len(operator) == 3:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = 0
                elif len(operator) == 4:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = str(x[k])[-4]
                if inputOneMode == '1':
                    inputOne = x[k+1]
                else:
                    inputOne = x[x[k+1]]
                if inputTwoMode == '1':
                    inputTwo = x[k+2]
                else:
                    inputTwo = x[x[k+2]]
                if inputOne == 0:
                    k = inputTwo
                else:
                    k = k+3
            elif modeOperator == '07':
                if len(operator) == 3:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = 0
                elif len(operator) == 4:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = str(x[k])[-4]
                if inputOneMode == '1':
                    inputOne = x[k+1]
                else:
                    inputOne = x[x[k+1]]
                if inputTwoMode == '1':
                    inputTwo = x[k+2]
                else:
                    inputTwo = x[x[k+2]]
                if inputOne < inputTwo:
                    x[x[k+3]] = 1
                else:
                    x[x[k+3]] = 0
                k = k+4
            elif modeOperator == '08':
                if len(operator) == 3:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = 0
                elif len(operator) == 4:
                    inputOneMode = str(x[k])[-3]
                    inputTwoMode = str(x[k])[-4]
                if inputOneMode == '1':
                    inputOne = x[k+1]
                else:
                    inputOne = x[x[k+1]]
                if inputTwoMode == '1':
                    inputTwo = x[k+2]
                else:
                    inputTwo = x[x[k+2]]
                if inputOne == inputTwo:
                    x[x[k+3]] = 1
                else:
                    x[x[k+3]] = 0
                k = k+4
    return x

# %%
intCode(opCodesTest)
# Out:
# 0
# PRESS ENTER TO CONTINUE.
# Operator = 3
# Enter an Integer: 5
# 2
# PRESS ENTER TO CONTINUE.
# Operator = 1
# 6
# PRESS ENTER TO CONTINUE.
# 238
# PRESS ENTER TO CONTINUE.
# 241
# PRESS ENTER TO CONTINUE.
# 247
# PRESS ENTER TO CONTINUE.
# 250
# PRESS ENTER TO CONTINUE.
# 256
# PRESS ENTER TO CONTINUE.
# 259
# PRESS ENTER TO CONTINUE.
# 265
# PRESS ENTER TO CONTINUE.
# 268
# PRESS ENTER TO CONTINUE.
# 274
# PRESS ENTER TO CONTINUE.
# 280
# PRESS ENTER TO CONTINUE.
# Operator = 1
# 284
# PRESS ENTER TO CONTINUE.
# Operator = 1101
# 288
# PRESS ENTER TO CONTINUE.
# 294
# PRESS ENTER TO CONTINUE.
# 300
# PRESS ENTER TO CONTINUE.
# Operator = 1
# 304
# PRESS ENTER TO CONTINUE.
# Operator = 1101
# 308
# PRESS ENTER TO CONTINUE.
# 314
# PRESS ENTER TO CONTINUE.
# 318
# PRESS ENTER TO CONTINUE.
# Operator = 102
# 322
# PRESS ENTER TO CONTINUE.
# 329
# PRESS ENTER TO CONTINUE.
# 333
# PRESS ENTER TO CONTINUE.
# Operator = 1002
# 337
# PRESS ENTER TO CONTINUE.
# 340
# ...

# %%
y = [3,21,1008,21,8,20,1005,20,22,107,8,21,20,1006,20,31,
1106,0,36,98,0,0,1002,21,125,20,4,20,1105,1,46,104,
999,1105,1,46,1101,1000,1,20,4,20,1105,1,46,98,99]
intCode(y)
# Out:
# 0
# PRESS ENTER TO CONTINUE.
# Operator = 3
# Enter an Integer: 12
# 2
# PRESS ENTER TO CONTINUE.
# 6
# PRESS ENTER TO CONTINUE.
# 9
# PRESS ENTER TO CONTINUE.
# 13
# PRESS ENTER TO CONTINUE.
# 16
# PRESS ENTER TO CONTINUE.
# 36
# PRESS ENTER TO CONTINUE.
# Operator = 1101
# 40
# PRESS ENTER TO CONTINUE.
# Operator = 4
# Test Value should be 0: 1001
# 42
# PRESS ENTER TO CONTINUE.
# 46
# PRESS ENTER TO CONTINUE.
# [3,
#  21,
#  1008,
#  21,
#  8,
#  20,
#  1005,
#  20,
#  22,
#  107,
#  8,
#  21,
#  20,
#  1006,
#  20,
#  31,
#  1106,
#  0,
#  36,
#  98,
#  1001,
#  12,
#  1002,
#  21,
#  125,
#  20,
#  4,
#  20,
#  1105,
#  1,
#  46,
#  104,
#  999,
#  1105,
#  1,
#  46,
#  1101,
#  1000,
#  1,
#  20,
#  4,
#  20,
#  1105,
#  1,
#  46,
#  98,
#  99]

# %%
y[2]
# Out:
# 1008
